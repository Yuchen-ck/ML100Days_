# %%
#Matplotlib
import matplotlib.pyplot as plt

# %%
years = [1000,1500,1600,1700,1750,1800,1850,
        1900,1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]

pops = [200,400,458,580,662,791,1000,
        1262,1650,2525,2758,3018,3322,3682,
        4061,4440,4853,5310,6520,
        6930,7349]

plt.plot(years,pops) #把需要畫出來的數值 直接丟進去
plt.show()

#刻度起始值ㄉ設定: 只能輸入一組數字，並放進plot()中

# %%
plt.plot(years,pops,color ='red') #加顏色
plt.show()

# %%
plt.plot(years,pops ,color ='red' ,linewidth = 5) #加粗細
plt.show()

# %%
#加圖片標題
#加x與y軸標題
plt.plot(years,pops ,color ='m' ,linewidth = 5)
plt.title("test",fontsize=30)
plt.xlabel("x-name")
plt.ylabel("y-name")
plt.show()

# %%
#設定刻度的大小與顏色等
#tick_params()
plt.plot(years,pops ,color ='m' ,linewidth = 5)
plt.tick_params(axis='both',color ='green' ,labelsize = 20)
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')

# %%
#兩條線

years = [1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]
pops = [2.5,2.7,3,3.3,3.6,4.0,
        4.4,4.8,5.3,6.1,6.5,6.9,7.3]
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]

lines = plt.plot(years,pops ,years,deaths)

# %%
lines = plt.plot(years,pops,'r-' ,years,deaths,'m--')
plt.grid(True)
plt.show()

# %%
#折線圖
lines = plt.plot(years,pops ,years,deaths)
plt.grid(True)
plt.setp(lines,marker = "o") 
plt.show()

# %%
data1 = [1 ,2 ,3 ,4 ,5 ,6 ,7 ,8]
data2 =[1,4,9,16,25,36,49,64]
year = [1,2,3,4,5,6,7,8]

#子圖1的佈局
plt.subplot(2,1,1)
plt.plot(seq,data1, "-<")

#子圖2的佈局
plt.subplot(2,1,2)
plt.plot(seq,data2, "-o")

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
#figure 多圖表設定
data1 = [1 ,2 ,3 ,4 ,5 ,6 ,7 ,8]
data2 =[1,4,9,16,25,36,49,64]
year = [1,2,3,4,5,6,7,8]

#圖表1
plt.figure(1)
plt.plot(year,data1, "-<")

#圖表2 
plt.figure(2)
plt.plot(year,data2, "-o")
 
plt.show() #圖表 1和 2

# %%
#figure()和 add_subplot()的ˋ應用
fig = plt.figure(figsize=(10,6)) #設定 figure 的尺寸
ax1 = fig.add_subplot(3,1,1) #分別畫出三格圖象，都可以針對特定圖象編輯與繪圖
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

plt.show()

# %%
#https://medium.com/%E5%8F%B0%E8%82%A1etf%E8%B3%87%E6%96%99%E7%A7%91%E5%AD%B8-%E7%A8%8B%E5%BC%8F%E9%A1%9E/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80-%E7%9C%8B%E7%9B%A4%E7%89%88%E9%9D%A2-%E4%B8%8A-%E5%9C%96%E6%A1%86%E6%95%99%E5%AD%B8-5d1baf57f5a7

# %%
# 3D 繪圖板
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 創建一個3d坐標系
fig = plt.figure()
ax = Axes3D(fig)
#直接查詢參數與設定
#help(plt.plot)
#help(np.random.sample)

# 利用x軸和y軸繪製sin曲線
x = np.linspace(0, 1, 100) # linspace創建等差陣列
y = np.cos(x * 2 * np.pi) / 2 + 0.5
# 通過zdir = 'z' 將資料繪製在z軸，zs = 0.5 則是將資料繪製在z = 0.5的地方
ax.plot(x, y, zs = 0.5, zdir = 'z', color = 'black', label = 'curve in (x, y)')

# %%
#自由移動位置的子圖 : Axes

#決定最外框
plt.axes([0.1,0.1,.8,.8])
plt.xticks([]), plt.yticks([])
plt.text(0.6,0.6, 'axes([0.1,0.1,.8,.8])',ha='center',va='center',size=20,alpha=.5)

#決定內框
plt.axes([0.2,0.2,.3,.3])
plt.xticks([]), plt.yticks([])
plt.text(0.5,0.5, 'axes([0.2,0.2,.3,.3])',ha='center',va='center',size=16,alpha=.5)

plt.show()
